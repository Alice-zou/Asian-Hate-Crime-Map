# %% [markdown]
# <a href="https://colab.research.google.com/github/Alice-zou/Asian-Hate-Crime-Map/blob/main/face_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install cmake

# %%
pip install dlib

# %%
pip install face_recognition

# %%
import PIL.Image
import PIL.ImageDraw
import face_recognition
import time as time

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
begin_time = time.time() # seconds
given_image = face_recognition.load_image_file('/content/drive/MyDrive/people.jpg')
face_locations = face_recognition.face_locations(given_image)
number_of_faces = len(face_locations)

pil_image = PIL.Image.fromarray(given_image)
for face_location in face_locations:
    top, left, bottom, right = face_location
    print('A face is detacted at pixel location Top: {}, Left: {}, Bottom: {}. Right: {}'.format(top, left, bottom, right))
    draw = PIL.ImageDraw.Draw(pil_image)
    draw.rectangle([left, top, right, bottom], outline='green', width=2)

print('We Found {} face(s) in this image.'.format(number_of_faces))

print(time.time()-begin_time)

pil_image
# Out:
# A face is detacted at pixel location Top: 113, Left: 193, Bottom: 164. Right: 141
# A face is detacted at pixel location Top: 89, Left: 290, Bottom: 132. Right: 247
# A face is detacted at pixel location Top: 130, Left: 141, Bottom: 182. Right: 89
# A face is detacted at pixel location Top: 44, Left: 89, Bottom: 95. Right: 37
# A face is detacted at pixel location Top: 65, Left: 223, Bottom: 108. Right: 180
# A face is detacted at pixel location Top: 107, Left: 533, Bottom: 159. Right: 481
# A face is detacted at pixel location Top: 67, Left: 440, Bottom: 118. Right: 389
# A face is detacted at pixel location Top: 38, Left: 366, Bottom: 90. Right: 314
# We Found 8 face(s) in this image.
# 0.17525768280029297
# <PIL.Image.Image image mode=RGB size=612x408 at 0x7FA877FAFE50>
