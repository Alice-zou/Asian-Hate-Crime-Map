# %% [markdown]
# <a href="https://colab.research.google.com/github/Alice-zou/Asian-Hate-Crime-Map/blob/main/Translate_between_languages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install git+https://github.com/neuml/txtai#egg=txtai[pipeline]

# %%
pip install "transformers==4.9.2"
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 29.6 MB/s
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.16
#     Uninstalling huggingface-hub-0.0.16:
#       Successfully uninstalled huggingface-hub-0.0.16
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.10.0
#     Uninstalling transformers-4.10.0:
#       Successfully uninstalled transformers-4.10.0
# ...

# %%
from transformers import AutoModelForCausalLM

# %%
# %%capture

from txtai.pipeline import Translation 

# Create translation model
translate = Translation()

# %%
translation = translate("Hello, your are a good guy", "zh")
translation
# Out:
# '你好,你是个好人'

# %%
languages = ["fr", "en", "zh", "hi", "ja"]

translations = [translate("Language Translation is Excellent", language) for language in languages]

english = translate(translations, "en")

for x, text in enumerate(translations):
  print("Original langues: %s" % languages[x])
  print("Translation: %s" % text)
  print("Back to English: %s" % english[x])
  print()
# Out:
# Downloading:   0%|          | 0.00/303M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/782k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.50M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/304M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/813k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Original langues: fr
# Translation: La traduction linguistique est excellente
# Back to English: Language Translation Is Excellent
#
# Original langues: en
# Translation: Language Translation is Excellent
# Back to English: Language Translation is Excellent
#
# Original langues: zh
# Translation: 语言翻译精妙
# Back to English: Excellent language translation.
# ...
